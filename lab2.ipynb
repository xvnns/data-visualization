# %% [markdown]
# ## Подключение необходимых библиотек

# %%
from plotnine import *
from plotnine.data import *

import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Тестовый датафрейм "mpg"

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# ## Простейшая визуализация с использованиме geom_point по осям displ и hwy

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"))
# Out:
# <ggplot: (167291857485)>

# %% [markdown]
# ### Постройте два графика: в одном из них одна из осей должна быть соответствовать столбцу с элементами-категориями, во втором – обе (например, "class" и "drv")

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="year", y="manufacturer"))
# Out:
# <ggplot: (167292049454)>

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="trans", y="manufacturer"))
# Out:
# <ggplot: (167291945015)>

# %% [markdown]
# ## Добавим красок, оттенков и форм в графики

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", color="class"))
# Out:
# <ggplot: (167291996512)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", alpha="manufacturer"))
# Out:
# <ggplot: (167291997136)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", shape="manufacturer"))
# Out:
# <ggplot: (167292355143)>

# %% [markdown]
# ### Попробуйте сделать два графика: в одном размер точек будет соответствовать столбцу с элементами-категориями, во втором – столбцу с элементами-значениями

# %%
# Type your code here...

ggplot(mpg) +\
geom_point(mapping = aes(x='trans', y='fl', color = 'fl', size = 'fl'))
# Out:
# <ggplot: (167292522067)>

# %%
# Type your code here...

ggplot(mpg) +\
geom_point(mapping = aes(x='cty', y='fl', size = 'cty'))
# Out:
# <ggplot: (167292669439)>

# %% [markdown]
# ## А что если сделать использовать в качестве источника визуального свойства "форма" непрерывную категорию (например hwy)?

# %%
# Type your code here...

ggplot(mpg) +\
geom_point(mapping = aes(x='hwy', y='fl', scale_fill_manual = 'hwy'))
# Out:
# <ggplot: (167292716807)>

# %% [markdown]
# ### Попробуйте сделать график с визуальным элементом, заданным условным оператором (например, color="displ < 5")

# %%
# Type your code here...

ggplot(mpg) +\
geom_point(mapping = aes(x='displ', y='fl', color = 'displ < 3.0'))
# Out:
# <ggplot: (167293087123)>

# %% [markdown]
# ### Попробуйте поэкспериментировать с графиками, где одной категории соответствуют различные визуальные элементы (пример ниже). Попробуйте привести пример, когда это имеет смысл.

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", stroke="hwy"))
# Out:
# <ggplot: (167292842213)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", stroke="hwy", color="manufacturer"))
# Out:
# <ggplot: (167292014484)>

# %%
# Type your code here...

ggplot(mpg) +\
geom_point(mapping = aes(x='displ', y='fl', size = 'cty', color = 'hwy'))
# Out:
# <ggplot: (167293151872)>

# %% [markdown]
# ## Использование панелей при визуализации

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_wrap("class", nrow=2)
# Out:
# <ggplot: (167292013713)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_grid("drv ~ cyl")
# Out:
# <ggplot: (167293795262)>

# %% [markdown]
# ### Что если использовать категорию с непрерывными значениями (например, hwy) для разделения на панели?

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="trans", y="cyl")) +\
facet_grid("drv ~ cyl")
# Out:
# <ggplot: (167292716138)>

# %% [markdown]
# ### Можно сделать только вертикальные или только горизонтальные панели, если использовать конструкцию типа (". ~ <категория>")

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="trans", y="displ")) +\
facet_grid(". ~ drv")
# Out:
# <ggplot: (167292708456)>

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="trans", y="displ")) +\
facet_grid("drv ~ .")
# Out:
# <ggplot: (167297461252)>

# %% [markdown]
# ### Что лучше использовать: цвета или панели? А для большого набора?

# %% [markdown]
# Лучше всего комбинировать, а для большого предпочтительней цвет - так гораздо проще увидеть разницу.

# %% [markdown]
# ## geom_smooth() позволяет получить сглаженную среднюю (в том числе, с доверительным интервалом).abs
# ### (это не сработает без библиотеки scikit-misc, и может не сработать даже с ней)

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"))
# Out:
# <ggplot: (167293590754)>

# %%
ggplot(data=mpg) +\
geom_smooth(mapping=aes(x="displ", y="hwy"))
# Out:
# <ggplot: (167293719808)>

# %%
ggplot(data=mpg) +\
geom_smooth(mapping=aes(x="displ", y="hwy", linetype="drv"))
# Out:
# <ggplot: (167293821028)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) +\
geom_point() +\
geom_smooth(mapping=aes(linetype="drv"))
# Out:
# <ggplot: (167293425875)>

# %% [markdown]
# ## Визуальные отображения в функции ggplot будут распространяться на все графики. Отдельные свойства каждого геометрического отображения будут относиться только к нему.

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="class")) +\
geom_smooth()
# Out:
# <ggplot: (167293834039)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="class")) +\
geom_smooth(data=mpg.loc[mpg["class"] == "subcompact"], se=False)
# Out:
# <ggplot: (167291857167)>

# %% [markdown]
# ## Попробуйте скомбинировать разные свойства разных слоёв

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="cty", y="hwy")) +\
geom_point(mapping=aes(color="model")) +\
geom_smooth(data=mpg.loc[mpg["model"] == "subcompact"], se=False)
# Out:
# <ggplot: (167292223735)>

# %% [markdown]
# # Какое геометрическое отображение вы будете использовать, чтобы нарисовать линейную диаграмму (обычный линейный график)?

# %%
# Type your code here...

ggplot(mpg) +\
geom_line(mapping = aes(x='cty', y='displ'))
# Out:
# <ggplot: (167293632110)>

# %% [markdown]
# ### Подберите подходящий код под следующие графики:
# <img src="supp/p1.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p2.png" alt="Drawing" style="width: 350px;"/></br>
# <img src="supp/p3.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p4.png" alt="Drawing" style="width: 350px;"/></br>
# <img src="supp/p5.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p6.png" alt="Drawing" style="width: 350px;"/>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point() +\
geom_smooth()
# Out:
# <ggplot: (167293631843)>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point() +\
geom_smooth(mapping=aes(linetype="drv"))
# Out:
# <ggplot: (167293058589)>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) +\
geom_point() +\
geom_smooth(mapping=aes(linetype="drv"))
# Out:
# <ggplot: (167293678286)>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="drv")) +\
geom_smooth()
# Out:
# <ggplot: (167297640617)>

# %%
# Type your code here...

ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) +\
geom_point() +\
geom_smooth(mapping=aes(linetype="drv"), color='black')
# Out:
# <ggplot: (167297603365)>

# %%
# Type your code here...

ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy",color="drv"))
# Out:
# <ggplot: (167297894073)>

# %% [markdown]
# ## Статистические свойства элементов категорий

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut"))
# Out:
# <ggplot: (167297943495)>

# %% [markdown]
# ### Что делает geom_col()? Чем он отличается от geom_bar()?

# %% [markdown]
# geom_col() представляет значения данных в виде столбцов, geom_bar () делает высоту полосы пропорциональной количеству наблюдений в каждой группе

# %%
ggplot(data=diamonds) +\
geom_col(mapping=aes(x="cut", y="clarity"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File D:\Programs\Python\Python310\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File D:\Programs\Python\Python310\lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\ggplot.py:95, in ggplot.__repr__(self)
#      91 def __repr__(self):
#      92     """
#      93     Print/show the plot
#      94     """
# ---> 95     self.__str__()
#      96     return '<ggplot: (%d)>' % self.__hash__()
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\ggplot.py:86, in ggplot.__str__(self)
#      82 def __str__(self):
#      83     """
#      84     Print/show the plot
#      85     """
# ---> 86     self.draw(show=True)
#      88     # Return and empty string so that print(p) is "pretty"
#      89     return ''
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\ggplot.py:203, in ggplot.draw(self, return_ggplot, show)
#     201 self = deepcopy(self)
#     202 with plot_context(self, show=show):
# --> 203     self._build()
#     205     # setup
#     206     figure, axs = self._create_figure()
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\ggplot.py:311, in ggplot._build(self)
#     308 layers.setup_data()
#     310 # Apply position adjustments
# --> 311 layers.compute_position(layout)
#     313 # Reset position scales, then re-train and map.  This
#     314 # ensures that facets have control over the range of
#     315 # a plot.
#     316 layout.reset_position_scales()
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\layer.py:79, in Layers.compute_position(self, layout)
#      77 def compute_position(self, layout):
#      78     for l in self:
# ---> 79         l.compute_position(layout)
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\layer.py:392, in layer.compute_position(self, layout)
#     390 params = self.position.setup_params(self.data)
#     391 data = self.position.setup_data(self.data, params)
# --> 392 data = self.position.compute_layer(data, params, layout)
#     393 self.data = data
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\positions\position.py:56, in position.compute_layer(cls, data, params, layout)
#      53     scales = layout.get_scales(pdata['PANEL'].iat[0])
#      54     return cls.compute_panel(pdata, scales, params)
# ---> 56 return groupby_apply(data, 'PANEL', fn)
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\utils.py:638, in groupby_apply(df, cols, func, *args, **kwargs)
#     634 lst = []
#     635 for _, d in df.groupby(cols):
#     636     # function fn should be free to modify dataframe d, therefore
#     637     # do not mark d as a slice of df i.e no SettingWithCopyWarning
# --> 638     lst.append(func(d, *args, **kwargs))
#     639 return pd.concat(lst, axis=axis, ignore_index=True)
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\positions\position.py:54, in position.compute_layer.<locals>.fn(pdata)
#      52     return pdata
#      53 scales = layout.get_scales(pdata['PANEL'].iat[0])
# ---> 54 return cls.compute_panel(pdata, scales, params)
#
# File D:\Programs\Python\Python310\lib\site-packages\plotnine\positions\position_stack.py:85, in position_stack.compute_panel(cls, data, scales, params)
#      78     return (trans.dataspace_is_numerical and
#      79             tname not in linear_transforms
#      80             )
#      82 # Positioning happens after scale transformation and stacking
#      83 # only works well for linear data. If the scale is non-linear,
#      84 # we undo the transformation, stack and redo the transformation
# ---> 85 trans = scales.y.trans
#      86 non_linear_trans = _is_non_linear_trans(trans)
#      87 if non_linear_trans:
#
# AttributeError: 'scale_y_discrete' object has no attribute 'trans'

# %% [markdown]
# ### Что произойдёт, если
# 'ggplot(data=diamonds) +\
# 'geom_bar(mapping=aes(x="cut", y="..prop.."), group=1)
# или
# ggplot(data=diamonds) +\
# geom_bar(mapping=aes(x="cut", fill="color", y="..prop.."))
# ### запустить без "group=1"? Почему?

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# Type your code here...

ggplot(mpg) +\
geom_bar(mapping=aes(x="fl", fill="trans"), group=1)
# Out:
# <ggplot: (167292085432)>

# %%
# Type your code here...

ggplot(mpg) +\
geom_bar(mapping=aes(x="fl", fill="trans"))
# Out:
# <ggplot: (167293646194)>

# %% [markdown]
# ## Модные графики с красивыми цветами

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="cut"))
# Out:
# <ggplot: (167292239647)>

# %% [markdown]
# ## При добавлении новых категорий в качестве цвета появляется новая функциональность

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"))
# Out:
# <ggplot: (167293102984)>

# %%
ggplot(data=diamonds, mapping=aes(x="cut", colour="clarity")) +\
geom_bar(fill=None, position="identity")
# Out:
# <ggplot: (167293160704)>

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"), position="fill")
# Out:
# <ggplot: (167297935222)>

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"), position="dodge")
# Out:
# <ggplot: (167297711582)>

# %% [markdown]
# ## Добавим jitter в scatter!

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"), position="jitter")
# Out:
# <ggplot: (167297631587)>

# %% [markdown]
# ### Зачем тут coord_fixed()? Что делает geom_abline()?

# %% [markdown]
# geom_abline() определяет уклон и пересечение линии
# coord_fixed() делает фиксированным соотношение между масштабами x и y

# %%
ggplot(data=mpg, mapping=aes(x="cty", y="hwy")) +\
geom_point() +\
geom_abline() +\
coord_fixed()
# Out:
# <ggplot: (167297602795)>

# %% [markdown]
# # Творческое задание
# ## Попробуйте использовать изученные средства plotnine для своего датасета (необязательно много и пока не надо строить сложные графики)

# %%
pokemon = pd.read_csv("Pokemon.csv", index_col=0)
pokemon.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
ggplot(data=pokemon) +\
geom_point(mapping=aes(x="Total", y="HP", color="Type 1"))
# Out:
# <ggplot: (167292902860)>

# %%
ggplot(pokemon) +\
geom_point(mapping = aes(x='Speed', y='Type 1', color = 'Total', size = 'Total'))
# Out:
# <ggplot: (167293741414)>

# %%
ggplot(data=pokemon) +\
geom_bar(mapping=aes(x="Generation", fill="Type 1"))
# Out:
# <ggplot: (167292384025)>
